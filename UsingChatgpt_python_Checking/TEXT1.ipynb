# %%
import socket

def start_tcp_server():
    server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    server_socket.bind(('localhost', 5000))
    server_socket.listen()
    while True:
        client_socket, client_address = server_socket.accept()
        print(f'Accepted connection from {client_address}')
        data = client_socket.recv(1024)
        client_socket.sendall(data)
        client_socket.close()

if __name__ == '__main__':
    start_tcp_server()

# %%
import tkinter as tk
from tkinter import messagebox

# 创建主窗口
root = tk.Tk()
root.title("漂亮的界面")

# 创建功能列表
def option1():
    messagebox.showinfo("选项 1", "您选择了选项 1")

def option2():
    messagebox.showinfo("选项 2", "您选择了选项 2")

def option3():
    messagebox.showinfo("选项 3", "您选择了选项 3")

# 创建选项
options = [("选项 1", option1),
           ("选项 2", option2),
           ("选项 3", option3)]

for option in options:
    tk.Button(root, text=option[0], command=option[1]).pack()

# 运行程序
root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox, ttk

# 创建主窗口
root = tk.Tk()
root.title("漂亮的界面")

# 创建功能列表
def option1():
    value = scale1.get()
    messagebox.showinfo("选项 1", "您选择了选项 1，滑动条的值为：" + str(value))

def option2():
    value = scale2.get()
    messagebox.showinfo("选项 2", "您选择了选项 2，滑动条的值为：" + str(value))

def option3():
    value = scale3.get()
    messagebox.showinfo("选项 3", "您选择了选项 3，滑动条的值为：" + str(value))

# 创建选项
options = [("选项 1", option1),
           ("选项 2", option2),
           ("选项 3", option3)]

for option in options:
    frame = tk.Frame(root)
    frame.pack(pady=10)
    tk.Button(frame, text=option[0], command=option[1]).pack(side=tk.LEFT)
    ttk.Scale(frame, from_=0, to=100, orient=tk.HORIZONTAL).pack(side=tk.LEFT)

# 运行程序
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk ,messagebox

def show_value1():
    value = scale1.get()
    messagebox.showinfo("Value", "Value of scale1 is " + str(value))

def show_value2():
    value = scale2.get()
    messagebox.showinfo("Value", "Value of scale2 is " + str(value))

def show_value3():
    value = scale3.get()
    messagebox.showinfo("Value", "Value of scale3 is " + str(value))

root = tk.Tk()
root.geometry("300x300")

# 创建选项
options = [("选项 1", show_value1),
           ("选项 2", show_value2),
           ("选项 3", show_value3)]

scale1 = tk.Scale(root, from_=0, to=100, orient=tk.HORIZONTAL)
scale1.pack()

scale2 = tk.Scale(root, from_=0, to=100, orient=tk.HORIZONTAL)
scale2.pack()

scale3 = tk.Scale(root, from_=0, to=100, orient=tk.HORIZONTAL)
scale3.pack()

for option in options:
    tk.Button(root, text=option[0], command=option[1]).pack()


root.mainloop()
