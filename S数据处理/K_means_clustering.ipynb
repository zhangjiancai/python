# %%
import pandas as pd
from pandas import DataFrame

# %%
from sklearn import datasets

# %% [markdown]
# 自动生成数据

# %%
centers = [[1,1],[-1,1],[0,0],[1,0]]
x,labels_truex = datasets.make_blobs(n_samples=750,n_features=4,centers=centers,cluster_std=[0.4,0.2,0.2,0.4],random_state=10)

# %%
y,labels_truey = datasets.make_circles(n_samples=1000,factor=0.2,noise=0.05)
z,labels_truez = datasets.make_moons(n_samples=1000,noise=0.05)

# %% [markdown]
# 数据可视化

# %%
import matplotlib.pyplot as plt

# %%
def datavisable(data,target):
    df = pd.DataFrame(data)
    df['target'] = target

    plt.scatter(data[:,0],data[:,1],c=target)
    '''
    df1 = df[df['target']==0]
    df2 = df[df['target']==1]
    df3 = df[df['target']==2]
    df4 = df[df['target']==3]
    df1.index = range(len(df1))    # type: ignore # 调整行索引（养成良好的数据处理习惯）
    df2.index = range(len(df2))  # type: ignore
    df3.index = range(len(df3))
    df4.index = range(len(df4))
    plt.figure(figsize=(4,4))
    plt.scatter(df1[0],df1[1],color='red')
    plt.scatter(df2[0],df2[1],color='green')
    plt.scatter(df3[0],df3[1],color='yellow')
    plt.scatter(df4[0],df4[1],color='blue')
    '''

# %%
datavisable(x,labels_truex)

# %%
datavisable(y,labels_truey)

# %%
datavisable(z,labels_truez)

# %% [markdown]
# K-means

# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
X = np.concatenate((x,y,z))
datavisable(X,"blue")

# %%
def KMeans_data(data,n):

    k_means = KMeans(n_clusters=n, random_state=10)

    k_means.fit(data)

    labels_true_predict = k_means.predict(data)
    return labels_true_predict

# %%
##print(KMeans_data(X,4))
datavisable(X,KMeans_data(X,4))

# %%
datavisable(x,KMeans_data(x,4))

# %% [markdown]
# DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
datavisable(X,DBSCAN(eps = 0.1, min_samples= 10 ).fit_predict(X))
